# %%
2+2
# Out:
# 4

# %%
import glob
import json
import pandas as pd

records = []

files = glob.glob(r"C:\Users\Aman Kumar Singh\Desktop\coverage_part1\*.jsonl")

serial_no = 1

for filename in files:

    with open(filename, "r", encoding="utf-8") as f:

        for line in f:

            if not line.strip():
                continue

            data = json.loads(line)

            factuality_scores = data.get("factuality_scores", {})
            coverage_scores = data.get("coverage_scores", {})

            records.append({
                "S.No": serial_no,
                "Index": data.get("index"),
                "Consultation": data.get("consultation"),
                "Report": data.get("report"),
                "Average Factuality Score": factuality_scores.get(
                    "average_factuality_score"
                ),
                "Coverage Score": coverage_scores.get(
                    "patient_coverage_score"
                )
            })

            serial_no += 1


df = pd.DataFrame(records)

print(df.head())

print(df.describe())
# Out:
# Empty DataFrame
# Columns: []
# Index: []
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 45
#      41 df = pd.DataFrame(records)
#      43 print(df.head())
# ---> 45 print(df.describe())
#
# File c:\Users\Aman Kumar Singh\anaconda3\envs\text_analytics\Lib\site-packages\pandas\core\generic.py:11426, in NDFrame.describe(self, percentiles, include, exclude)
#   11180 @final
#   11181 def describe(
#   11182     self,
#    (...)  11185     exclude=None,
#   11186 ) -> Self:
#   11187     """
#   11188     Generate descriptive statistics.
#   11189
#    (...)  11424     max            NaN      3.0
#   11425     """
# > 11426     return describe_ndframe(
#   11427         obj=self,
#   11428         include=include,
#   11429         exclude=exclude,
#   11430         percentiles=percentiles,
#   11431     ).__finalize__(self, method="describe")
#
# ...

# %%
files = glob.glob(r"C:\Users\Aman Kumar Singh\Desktop\coverage_part1\*.jsonl")

print(files)
# Out:
# []
